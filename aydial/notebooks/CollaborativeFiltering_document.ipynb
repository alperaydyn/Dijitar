# %% [markdown]
# # İşbirlikçi Filtreleme

# %% [markdown]
# https://www.google.com/url?sa=i&url=https%3A%2F%2Fpredictivehacks.com%2Fitem-based-collaborative-filtering-in-python%2F&psig=AOvVaw1z1IduvwAtBe0Hw75MWfJr&ust=1643638392664000&source=images&cd=vfe&ved=0CAsQjRxqFwoTCLjK-qbU2fUCFQAAAAAdAAAAABBj
# ![image.png](attachment:image.png)

# %% [markdown]
# https://www.i2tutorials.com/recommender-system-collaborative-filtering/
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# https://developers.google.com/machine-learning/recommendation/collaborative/basics
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)
